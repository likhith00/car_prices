# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/car_prices.csv',sep=',')

# %%
df.head()
# Out:
#    car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0       1          3        2         1           0           1        0
# 1       2          3        3         1           0           1        0
# 2       3          1        1         1           0           1        2
# 3       4          2        4         1           0           0        3
# 4       5          2        5         1           0           0        3
#
#    drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0           2               0       88.6  ...         130           5
# 1           2               0       88.6  ...         130           5
# 2           2               0       94.5  ...         152           5
# 3           1               0       99.8  ...         109           5
# 4           0               0       99.4  ...         136           5
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
df.describe().T
# Out:
#                   count          mean          std      min      25%  \
# car_ID            205.0    103.000000    59.322565     1.00    52.00
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# CarName           205.0     77.209756    41.014583     0.00    44.00
# fueltype          205.0      0.902439     0.297446     0.00     1.00
# aspiration        205.0      0.180488     0.385535     0.00     0.00
# doornumber        205.0      0.439024     0.497483     0.00     0.00
# carbody           205.0      2.614634     0.859081     0.00     2.00
# drivewheel        205.0      1.326829     0.556171     0.00     1.00
# enginelocation    205.0      0.014634     0.120377     0.00     0.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# ...

# %%
overview = df.describe()

# %%
overview.loc[["min","max"]].to_json("../prediction_service/schema_in.json")
